# %% [markdown]
# ## Libraries

# %%
import os
import collections
import numpy as np
import pandas as pd

# %%
# additional libraries
! pip install icalendar
# Out:
# Requirement already satisfied: icalendar in c:\users\louis\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (5.0.10)
# Requirement already satisfied: python-dateutil in c:\users\louis\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from icalendar) (2.8.2)
# Requirement already satisfied: pytz in c:\users\louis\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from icalendar) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in c:\users\louis\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from python-dateutil->icalendar) (1.16.0)
# WARNING: Ignoring invalid distribution -yzmq (c:\users\louis\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages)
# WARNING: Ignoring invalid distribution -yzmq (c:\users\louis\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages)
# WARNING: Ignoring invalid distribution -yzmq (c:\users\louis\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages)
# WARNING: Ignoring invalid distribution -yzmq (c:\users\louis\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages)
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3
# [notice] To update, run: C:\Users\louis\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Paths

# %%
# base folder path
base_path = ''

# if we are on google colab, we mount the drive
if 'google.colab' in str(get_ipython()):
    from google.colab import drive
    drive.mount('/content/drive')
    base_path = './drive/Shareddrives/2020-Makerspace-tracking'

# if we are running it locally, we use the standard gdrive path
else:
    curr_dir = os.getcwd().split('2020-Makerspace-tracking')[0]
    base_path = os.path.join(curr_dir,'2020-Makerspace-tracking')

# %%
# folders we'll be working with
agg_path = os.path.join(base_path, 'Data', '2022-Spr-T519', 'aggregated')
data_path = os.path.join(base_path, 'Data', '2022-Spr-T519', 'poseconnect')
#analysis_path = os.path.join(base_path, 'Analysis', '2022-Spr-Week7')

# %% [markdown]
# ## Helpers

# %%
# load the script
script = os.path.join(base_path, 'Analysis', 'helpers', '[ Archives ]', 'augment_df.py')
# %run "$script"

# %%
# load the script for generating correlation heatmaps
script_heatmap = os.path.join(base_path, 'Analysis', 'helpers', 'heatmap.py')
# %run "$script_heatmap"

# %% [markdown]
# ## Data

# %% [markdown]
# ### Survey

# %%
scores_path = os.path.join(agg_path, 'outcome_participants_scores.csv')
scores_df = pd.read_csv(scores_path)
scores_df.head()
# Out:
#    Unnamed: 0 student_id                          email  mid_gain_se  \
# 0           0     aashna    aashnasaraf@gse.harvard.edu           -5
# 1           1     conner       ceastman@gse.harvard.edu           -7
# 2           2      chali  chalisakaewla@gse.harvard.edu           -1
# 3           3     denise  denisefabella@gse.harvard.edu           -4
# 4           4      helen   helen_turner@gse.harvard.edu            3
#
#    final_raw_se  total_gain_se  mid_gain_com  mid_gain_se_norm  \
# 0             8             -4        0.3750          0.250000
# 1            14             -1        2.0000          0.083333
# 2            10              6        0.5000          0.583333
# 3             7             -2       -0.0625          0.333333
# 4            16              6       -0.7500          0.916667
#
#    mid_gain_com_norm  final_raw_com  total_gain_com     score  enjoyment  \
# 0           0.409091          1.750           0.500  0.164773   2.769231
# 1           1.000000          2.000           2.000  0.479167   2.384615
# 2           0.454545          1.500           1.500  0.509470   2.000000
# 3           0.250000          1.125           0.375  0.437500   3.153846
# 4           0.000000          1.500          -0.500  0.645833   3.071429
#
#    stress_level  time_on_assignment
# 0      2.153846            5.923077
# 1      2.615385            5.769231
# 2      1.846154            4.384615
# 3      2.230769            4.384615
# 4      1.928571            4.285714

# %% [markdown]
# ### Sensor data

# %%
# go through the poseconnect data
folder = os.path.join(data_path, 'poseconnect_cleaned')
for dir in os.listdir(folder):
    if '2022' in dir:
        subfolder = os.path.join(folder, dir)
        for subfile in os.listdir(subfolder):

            # we only care about the 3d reconstructed data
            if subfile.endswith('.csv') and '3d' in subfile:
                path = os.path.join(subfolder, subfile)
                csv = path.replace('3d_', 'summary_')

                # if the summary file already exists, we skip it
                if os.path.isfile(csv): continue

                # we read the data and add AOI columns
                data = pd.read_csv(path)
                add_aoi_to_df(data)

                # summarize the data by student, hour, aoi and save it
                summary = data.groupby(['student_id','timestamp', 'aoi']).size().unstack()
                summary.to_csv(csv)

# %% [markdown]
# ### Combine the two together

# %%
import glob
import pathlib

csv_files = list(pathlib.Path(folder).rglob('*.csv'))
summary_files = [x for x in csv_files if 'summary_' in str(x)]
summary_files
# Out:
# [WindowsPath('c:/Users/louis/Desktop/Semester-Project/2020-Makerspace-tracking/Data/2022-Spr-T519/poseconnect/poseconnect_cleaned/2022-03-03/summary_2022-03-03.csv'),
#  WindowsPath('c:/Users/louis/Desktop/Semester-Project/2020-Makerspace-tracking/Data/2022-Spr-T519/poseconnect/poseconnect_cleaned/2022-03-04/summary_2022-03-04.csv'),
#  WindowsPath('c:/Users/louis/Desktop/Semester-Project/2020-Makerspace-tracking/Data/2022-Spr-T519/poseconnect/poseconnect_cleaned/2022-03-05/summary_2022-03-05.csv'),
#  WindowsPath('c:/Users/louis/Desktop/Semester-Project/2020-Makerspace-tracking/Data/2022-Spr-T519/poseconnect/poseconnect_cleaned/2022-03-06/summary_2022-03-06.csv'),
#  WindowsPath('c:/Users/louis/Desktop/Semester-Project/2020-Makerspace-tracking/Data/2022-Spr-T519/poseconnect/poseconnect_cleaned/2022-03-07/summary_2022-03-07.csv'),
#  WindowsPath('c:/Users/louis/Desktop/Semester-Project/2020-Makerspace-tracking/Data/2022-Spr-T519/poseconnect/poseconnect_cleaned/2022-03-08/summary_2022-03-08.csv'),
#  WindowsPath('c:/Users/louis/Desktop/Semester-Project/2020-Makerspace-tracking/Data/2022-Spr-T519/poseconnect/poseconnect_cleaned/2022-03-09/summary_2022-03-09.csv')]

# %%
# combine all the dfs together
main_df = None

for csv in summary_files:
    df = pd.read_csv(csv)
    df.insert(0,'file', csv)
    if type(main_df) == type(None): main_df = df
    else: main_df = pd.concat(main_df, df, ignore_index=True)

#main_df = main_df.groupby(['student_id']).sum()
main_df
# Out:
# student_id
# aashna        76841
# alaa         204185
# bertrand       9477
# chali        773104
# conner       766976
# daniel       593834
# denise       250627
# hoa          425185
# iulian        69162
# ji su        502828
# juan         784199
# marc         399945
# melissa      327055
# miaoya       185338
# natalie      741219
# rachel       178911
# rebecca      360030
# rhea         687254
# rui          644721
# sara         193303
# xiaoyi       454528
# yani        1124619
# dtype: int64

# %%
master_df = main_df.merge(scores_df, on='student_id')
master_df
# Out:
#    student_id  is_with_count  Unnamed: 0  \
# 0      aashna          76841           0
# 1       chali         773104           2
# 2      conner         766976           1
# 3      denise         250627           3
# 4         hoa         425185           5
# 5       ji su         502828           6
# 6        juan         784199           7
# 7     melissa         327055           9
# 8      miaoya         185338           8
# 9     natalie         741219          10
# 10     rachel         178911          11
# 11    rebecca         360030          16
# 12       rhea         687254          12
# 13        rui         644721          13
# 14       sara         193303          14
# 15     xiaoyi         454528          15
# 16       yani        1124619          17
#
#                                       email  mid_gain_se  final_raw_se  \
# 0               aashnasaraf@gse.harvard.edu           -5             8
# 1             chalisakaewla@gse.harvard.edu           -1            10
# 2                  ceastman@gse.harvard.edu           -7            14
# 3             denisefabella@gse.harvard.edu           -4             7
# 4                   hoapham@gse.harvard.edu           -5             8
# 5                      jlee@gse.harvard.edu           -1            15
# 6   juanpablo_garcesramirez@gse.harvard.edu            0             8
# 7                     mkain@gse.harvard.edu            0            14
# 8               miaoyazhong@gse.harvard.edu            3            15
# 9                   nvarkey@gse.harvard.edu           -1            15
# 10             rachelparker@gse.harvard.edu            0            10
# 11                 xueru_yu@gse.harvard.edu           -3             1
# 12                  rsharma@gse.harvard.edu            0             8
# 13                  ruizhou@gse.harvard.edu            0             8
# 14             sara_zaghlul@gse.harvard.edu           -8             7
# 15              xiaoyizhong@gse.harvard.edu            4            15
# 16                   yanisu@gse.harvard.edu            4            15
#
#     total_gain_se  mid_gain_com  mid_gain_se_norm  mid_gain_com_norm  \
# 0              -4        0.3750          0.250000           0.409091
# 1               6        0.5000          0.583333           0.454545
# 2              -1        2.0000          0.083333           1.000000
# 3              -2       -0.0625          0.333333           0.250000
# 4              -5       -0.6875          0.250000           0.022727
# 5               1        0.1250          0.583333           0.318182
# 6              -1        0.2500          0.666667           0.363636
# 7               1        1.5000          0.666667           0.818182
# 8              10        0.8750          0.916667           0.590909
# 9               7       -0.0625          0.583333           0.250000
# 10              0        0.0000          0.666667           0.272727
# 11             -2       -0.3750          0.416667           0.136364
# 12              1        0.0000          0.666667           0.272727
# 13              0        0.0000          0.666667           0.272727
# 14             -9       -0.1250          0.000000           0.227273
# 15              3        0.0000          1.000000           0.272727
# 16              9        0.3750          1.000000           0.409091
#
#     final_raw_com  total_gain_com     score  enjoyment  stress_level  \
# 0          1.7500          0.5000  0.164773   2.769231      2.153846
# 1          1.5000          1.5000  0.509470   2.000000      1.846154
# 2          2.0000          2.0000  0.479167   2.384615      2.615385
# 3          1.1250          0.3750  0.437500   3.153846      2.230769
# 4          2.0000          0.0000  0.318182   3.153846      2.000000
# 5          1.6875          0.1875  0.642045   3.230769      1.769231
# 6          2.0000          1.1250  0.590909   3.857143      2.357143
# 7          1.1250          1.1250  0.454545   2.538462      1.538462
# 8          2.0000          0.8750  0.793561   3.230769      2.923077
# 9          2.0000          1.0000  0.583333   3.076923      2.692308
# 10         1.3750         -0.1250  0.609848   4.000000      2.357143
# 11         0.8750          0.0000  0.263258   2.916667      2.250000
# 12         1.0000          0.0000  0.443182   2.357143      2.071429
# 13         1.0000          0.0000  0.526515   2.615385      2.230769
# 14         1.5000         -0.1250  0.306818   3.000000      1.846154
# 15         2.0000          0.0000  0.526515   2.857143      2.214286
# 16         2.0000          0.3750  0.477273   2.769231      1.692308
#
#     time_on_assignment
# 0             5.923077
# 1             4.384615
# 2             5.769231
# 3             4.384615
# 4             5.923077
# 5             4.230769
# 6             6.142857
# 7             4.076923
# 8             3.461538
# 9             5.000000
# 10            5.571429
# 11            4.833333
# 12            7.571429
# 13            5.923077
# 14            5.461538
# 15            5.285714
# 16            4.384615

# %% [markdown]
# ## Correlations

# %%
master_df.columns
# Out:
# Index(['student_id', 'is_with_count', 'Unnamed: 0', 'email', 'mid_gain_se',
#        'final_raw_se', 'total_gain_se', 'mid_gain_com', 'mid_gain_se_norm',
#        'mid_gain_com_norm', 'final_raw_com', 'total_gain_com', 'score',
#        'enjoyment', 'stress_level', 'time_on_assignment'],
#       dtype='object')

# %%
# define our predictors (rows) and outcomes (columns)
predictors = ['student_id']
outcomes = ['mid_gain_se', 'mid_gain_com', 'enjoyment', 'stress_level','mid_gain_se_norm', 'mid_gain_com_norm', 'enjoyment','stress_level', 'score']

compute_correlation(master_df, predictors, outcomes)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\louis\Desktop\Semester-Project\[ Correlation template ].ipynb Cell 21 line 5
#       <a href='vscode-notebook-cell:/c%3A/Users/louis/Desktop/Semester-Project/%5B%20Correlation%20template%20%5D.ipynb#X26sZmlsZQ%3D%3D?line=1'>2</a> predictors = ['student_id']
#       <a href='vscode-notebook-cell:/c%3A/Users/louis/Desktop/Semester-Project/%5B%20Correlation%20template%20%5D.ipynb#X26sZmlsZQ%3D%3D?line=2'>3</a> outcomes = ['mid_gain_se', 'mid_gain_com', 'enjoyment', 'stress_level','mid_gain_se_norm', 'mid_gain_com_norm', 'enjoyment','stress_level', 'score']
# ----> <a href='vscode-notebook-cell:/c%3A/Users/louis/Desktop/Semester-Project/%5B%20Correlation%20template%20%5D.ipynb#X26sZmlsZQ%3D%3D?line=4'>5</a> compute_correlation(master_df, predictors, outcomes)
#
# File ~\Desktop\Semester-Project\2020-Makerspace-tracking\Analysis\helpers\heatmap.py:26, in compute_correlation(df, outcomes, predictors, test, height, plot_r, plot_p, sort_by, title, save_fig)
#      23     height = int(len(predictors) * 2)
#      25 # compute the correlations
# ---> 26 filtered = df[list(set(outcomes+predictors))].astype('float')
#      27 correlations = filtered.corr()
#      29 #compute the p-value for each correlation
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\generic.py:6534, in NDFrame.astype(self, dtype, copy, errors)
#    6530     results = [ser.astype(dtype, copy=copy) for _, ser in self.items()]
#    6532 else:
#    6533     # else, only a single dtype is given
# -> 6534     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6535     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6536     return res.__finalize__(self, method="astype")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\internals\managers.py:414, in BaseBlockManager.astype(self, dtype, copy, errors)
#     411 elif using_copy_on_write():
#     412     copy = False
# --> 414 return self.apply(
#     415     "astype",
#     416     dtype=dtype,
#     417     copy=copy,
#     418     errors=errors,
#     419     using_cow=using_copy_on_write(),
#     420 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\internals\managers.py:354, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     352         applied = b.apply(f, **kwargs)
#     353     else:
# --> 354         applied = getattr(b, f)(**kwargs)
#     355     result_blocks = extend_blocks(applied, result_blocks)
#     357 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\internals\blocks.py:616, in Block.astype(self, dtype, copy, errors, using_cow)
#     596 """
#     597 Coerce to the new dtype.
#     598
#    (...)
#     612 Block
#     613 """
#     614 values = self.values
# --> 616 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     618 new_values = maybe_coerce_values(new_values)
#     620 refs = None
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\dtypes\astype.py:238, in astype_array_safe(values, dtype, copy, errors)
#     235     dtype = dtype.numpy_dtype
#     237 try:
# --> 238     new_values = astype_array(values, dtype, copy=copy)
#     239 except (ValueError, TypeError):
#     240     # e.g. _astype_nansafe can fail on object-dtype of strings
#     241     #  trying to convert to float
#     242     if errors == "ignore":
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\dtypes\astype.py:183, in astype_array(values, dtype, copy)
#     180     values = values.astype(dtype, copy=copy)
#     182 else:
# --> 183     values = _astype_nansafe(values, dtype, copy=copy)
#     185 # in pandas we don't store numpy str dtypes, so convert to object
#     186 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\dtypes\astype.py:134, in _astype_nansafe(arr, dtype, copy, skipna)
#     130     raise ValueError(msg)
#     132 if copy or arr.dtype == object or dtype == object:
#     133     # Explicit copy, or required since NumPy can't view from / to object.
# --> 134     return arr.astype(dtype, copy=True)
#     136 return arr.astype(dtype, copy=copy)
#
# ValueError: could not convert string to float: 'aashna'
